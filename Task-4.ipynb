# %% [markdown]
# # IMPROVED IQR METHOD

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from collections import defaultdict

# %%
# Load the dataset
file_path = 'cleaned_dataset.csv'  # Replace with actual file path
data = pd.read_csv(file_path)

# Define the sensor-related columns to check for outliers
sensor_columns = ['Acc X', 'Acc Y', 'Acc Z', 'gyro_x', 'gyro_y', 'gyro_z']

# Define the function to detect outliers using skew-adjusted Tukey's IQR method
def detect_outliers_adjusted_tukey(data, column, multiplier=1.5):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1

    # Calculate skewness
    skew = data[column].skew()

    # Adjust multipliers based on skewness
    lower_mult = multiplier * (1 - skew)
    upper_mult = multiplier * (1 + skew)
    
    # Calculate skew-adjusted bounds
    lower_bound = Q1 - lower_mult * IQR
    upper_bound = Q3 + upper_mult * IQR

    # Identify outliers based on adjusted bounds
    outliers = data[(data[column] < lower_bound) | (data[column] > upper_bound)]
    
    return IQR, outliers, lower_bound, upper_bound

# Apply the function to each sensor column and print the results
for col in sensor_columns:
    iqr, outliers, lower_bound, upper_bound = detect_outliers_adjusted_tukey(data, col, multiplier=1.5)
    print(f"Column: {col}")
    print(f"IQR: {iqr}")
    print(f"Lower Bound: {lower_bound}, Upper Bound: {upper_bound}")
    print(f"Outliers Detected: {len(outliers)}")
    print(outliers)  # Display outlier rows for each column
    print("\n")
# Out:
# Column: Acc X
# IQR: 0.3895092391999997
# Lower Bound: -0.8505992423053192, Upper Bound: 0.7074377144946795
# Outliers Detected: 2020
#        Longitude   Latitude  Speed     Distance      Time     Acc X     Acc Y  \
# 96     73.822660  18.501627  0.000     0.025645  18-45-22  0.832253 -0.298408
# 97     73.822660  18.501627  0.000     0.025645  18-45-22  0.799070 -0.243648
# 98     73.822660  18.501627  0.000     0.025645  18-45-22  0.870786 -0.109471
# 99     73.822660  18.501627  0.000     0.025645  18-45-22  0.742543 -0.062337
# 164    73.822520  18.501616  0.732    14.906174  18-45-29 -1.082216  1.019267
# ...          ...        ...    ...          ...       ...       ...       ...
# 14191  73.822813  18.501587  0.000  2096.573200  17-27-29  1.520395  1.565442
# 14192  73.822813  18.501587  0.000  2096.573200  17-27-29  1.229296  1.503951
# 14193  73.822813  18.501587  0.000  2096.573200  17-27-29  1.619212  1.501497
# 14201  73.822813  18.501587  0.000  2096.573200  17-27-30 -0.980432 -0.112483
# 14202  73.822813  18.501587  0.000  2096.573200  17-27-30 -1.006064  0.094678
#
#           Acc Z  Heading    gyro_x    gyro_y    gyro_z  label
# 96     0.370986    352.0 -0.024211  0.007167  0.030462      0
# 97     0.340208    352.0 -0.040948  0.000448  0.045123      0
# 98     0.336063    352.0 -0.040704 -0.011158  0.054652      0
# 99     0.166326    352.0 -0.032152 -0.010181  0.057218      0
# 164   -3.491384    352.0 -0.270756 -0.065159  0.042557      1
# ...         ...      ...       ...       ...       ...    ...
# 14191 -1.570513      6.0 -0.105456 -0.015903 -0.037609      1
# 14192 -1.118551      6.0 -0.103867 -0.004296 -0.070962      1
# 14193 -1.127005      6.0 -0.135266 -0.000753 -0.120076      1
# 14201  0.827205     11.0 -0.075401 -0.082732 -0.033333      1
# 14202  0.536214     11.0 -0.058053 -0.067704 -0.024170      1
#
# [2020 rows x 13 columns]
#
#
# Column: Acc Y
# IQR: 0.3394834073500004
# Lower Bound: -0.45153829034227866, Upper Bound: 0.9063953390577228
# Outliers Detected: 1750
#        Longitude   Latitude  Speed     Distance      Time     Acc X     Acc Y  \
# 134    73.822616  18.501623  0.510     4.674526  18-45-26  0.390531 -0.463750
# 164    73.822520  18.501616  0.732    14.906174  18-45-29 -1.082216  1.019267
# 165    73.822520  18.501616  0.732    14.906174  18-45-29 -1.130505  1.642241
# 166    73.822520  18.501616  0.732    14.906174  18-45-29 -1.080892  1.910658
# 167    73.822520  18.501616  0.732    14.906174  18-45-29 -1.555064  1.752859
# ...          ...        ...    ...          ...       ...       ...       ...
# 14191  73.822813  18.501587  0.000  2096.573200  17-27-29  1.520395  1.565442
# 14192  73.822813  18.501587  0.000  2096.573200  17-27-29  1.229296  1.503951
# 14193  73.822813  18.501587  0.000  2096.573200  17-27-29  1.619212  1.501497
# 14199  73.822813  18.501587  0.000  2096.573200  17-27-30 -0.644297 -0.677599
# 14200  73.822813  18.501587  0.000  2096.573200  17-27-30 -0.679232 -0.521125
#
#           Acc Z  Heading    gyro_x    gyro_y    gyro_z  label
# 134   -0.921528    357.0  0.008165  0.009611 -0.026349      0
# 164   -3.491384    352.0 -0.270756 -0.065159  0.042557      1
# 165   -3.783913    353.0 -0.087252 -0.011769 -0.000570      1
# 166   -3.452731    353.0  0.001934 -0.012014  0.004195      1
# 167   -4.026543    353.0  0.119587  0.020118 -0.081204      1
# ...         ...      ...       ...       ...       ...    ...
# 14191 -1.570513      6.0 -0.105456 -0.015903 -0.037609      1
# 14192 -1.118551      6.0 -0.103867 -0.004296 -0.070962      1
# 14193 -1.127005      6.0 -0.135266 -0.000753 -0.120076      1
# 14199  1.836836     10.0 -0.060740 -0.101668  0.016025      1
# 14200  1.430832     10.0 -0.083220 -0.088474 -0.016717      1
#
# [1750 rows x 13 columns]
#
#
# Column: Acc Z
# IQR: 0.6959310542500005
# Lower Bound: -1.8070118855318122, Upper Bound: 0.9767123314681897
# Outliers Detected: 1956
#        Longitude   Latitude  Speed     Distance      Time     Acc X     Acc Y  \
# 163    73.822520  18.501616  0.732    14.906174  18-45-29 -0.477100  0.296066
# 164    73.822520  18.501616  0.732    14.906174  18-45-29 -1.082216  1.019267
# 165    73.822520  18.501616  0.732    14.906174  18-45-29 -1.130505  1.642241
# 166    73.822520  18.501616  0.732    14.906174  18-45-29 -1.080892  1.910658
# 167    73.822520  18.501616  0.732    14.906174  18-45-29 -1.555064  1.752859
# ...          ...        ...    ...          ...       ...       ...       ...
# 14200  73.822813  18.501587  0.000  2096.573200  17-27-30 -0.679232 -0.521125
# 14208  73.822813  18.501587  0.000  2096.573200  17-27-31 -0.015534 -0.242085
# 14209  73.822813  18.501587  0.000  2096.573200  17-27-31 -0.053371 -0.184421
# 14210  73.822813  18.501587  0.000  2096.573200  17-27-31 -0.160534 -0.148912
# 14211  73.822813  18.501587  0.000  2096.573200  17-27-31 -0.069212 -0.074595
#
#           Acc Z  Heading    gyro_x    gyro_y    gyro_z  label
# 163   -2.016198    354.0 -0.211380 -0.085073  0.041213      1
# 164   -3.491384    352.0 -0.270756 -0.065159  0.042557      1
# 165   -3.783913    353.0 -0.087252 -0.011769 -0.000570      1
# 166   -3.452731    353.0  0.001934 -0.012014  0.004195      1
# 167   -4.026543    353.0  0.119587  0.020118 -0.081204      1
# ...         ...      ...       ...       ...       ...    ...
# 14200  1.430832     10.0 -0.083220 -0.088474 -0.016717      1
# 14208  1.143199     11.0  0.035410 -0.012238 -0.025880      1
# 14209  1.217123     11.0  0.016962 -0.009672 -0.024292      1
# 14210  1.322266     11.0  0.010731 -0.013582 -0.011220      1
# 14211  1.173278     11.0  0.017939 -0.006740 -0.003889      1
#
# [1956 rows x 13 columns]
#
#
# Column: gyro_x
# IQR: 0.05314527924999982
# Lower Bound: -0.11164499910048227, Upper Bound: 0.10093611789951704
# Outliers Detected: 2152
#        Longitude   Latitude  Speed     Distance      Time     Acc X     Acc Y  \
# 162    73.822520  18.501616  0.732    14.906174  18-45-29 -0.103867  0.272178
# 163    73.822520  18.501616  0.732    14.906174  18-45-29 -0.477100  0.296066
# 164    73.822520  18.501616  0.732    14.906174  18-45-29 -1.082216  1.019267
# 167    73.822520  18.501616  0.732    14.906174  18-45-29 -1.555064  1.752859
# 168    73.822520  18.501616  0.732    14.906174  18-45-29 -1.107155  1.488280
# ...          ...        ...    ...          ...       ...       ...       ...
# 14183  73.822813  18.501587  0.000  2096.573200  17-27-28  0.599242 -1.570705
# 14184  73.822813  18.501587  0.000  2096.573200  17-27-28  0.687793 -1.498275
# 14185  73.822813  18.501587  0.000  2096.573200  17-27-28  0.434999 -1.207874
# 14186  73.822813  18.501587  0.000  2096.573200  17-27-28  0.559245 -0.635276
# 14193  73.822813  18.501587  0.000  2096.573200  17-27-29  1.619212  1.501497
#
#           Acc Z  Heading    gyro_x    gyro_y    gyro_z  label
# 162   -1.040949    354.0 -0.115107 -0.088494  0.054286      1
# 163   -2.016198    354.0 -0.211380 -0.085073  0.041213      1
# 164   -3.491384    352.0 -0.270756 -0.065159  0.042557      1
# 167   -4.026543    353.0  0.119587  0.020118 -0.081204      1
# 168   -1.124722    355.0  0.404006  0.036000 -0.100874      1
# ...         ...      ...       ...       ...       ...    ...
# 14183  2.266081      6.0  0.313598 -0.170330  0.030930      1
# 14184  1.748363      6.0  0.237973 -0.169719  0.032274      1
# 14185  1.199026      6.0  0.186171 -0.190366  0.066849      1
# 14186  0.509873      6.0  0.145488 -0.192565  0.073691      1
# 14193 -1.127005      6.0 -0.135266 -0.000753 -0.120076      1
#
# [2152 rows x 13 columns]
#
#
# Column: gyro_y
# IQR: 0.03286455024999997
# Lower Bound: -0.05965862345603692, Upper Bound: 0.07179957754396298
# Outliers Detected: 2569
#        Longitude   Latitude  Speed     Distance      Time     Acc X     Acc Y  \
# 148    73.822586  18.501623  0.746     7.843655  18-45-27  0.404259  0.252356
# 149    73.822553  18.501624  0.718    11.361694  18-45-27  0.330370  0.505911
# 150    73.822553  18.501624  0.718    11.361694  18-45-27  0.347886  0.571110
# 151    73.822553  18.501624  0.718    11.361694  18-45-27  0.201260  0.621476
# 152    73.822553  18.501624  0.718    11.361694  18-45-28  0.184810  0.584877
# ...          ...        ...    ...          ...       ...       ...       ...
# 14198  73.822813  18.501587  0.000  2096.573200  17-27-30 -0.464301 -0.451292
# 14199  73.822813  18.501587  0.000  2096.573200  17-27-30 -0.644297 -0.677599
# 14200  73.822813  18.501587  0.000  2096.573200  17-27-30 -0.679232 -0.521125
# 14201  73.822813  18.501587  0.000  2096.573200  17-27-30 -0.980432 -0.112483
# 14202  73.822813  18.501587  0.000  2096.573200  17-27-30 -1.006064  0.094678
#
#           Acc Z  Heading    gyro_x    gyro_y    gyro_z  label
# 148   -0.231965    356.0 -0.008939 -0.067602  0.009815      0
# 149   -0.460931    356.0 -0.003930 -0.073467  0.007249      0
# 150   -0.566340    355.0  0.038098 -0.078842  0.012747      0
# 151   -0.598182    355.0  0.068641 -0.070168 -0.005335      0
# 152   -0.498392    354.0  0.049582 -0.068213 -0.009000      0
# ...         ...      ...       ...       ...       ...    ...
# 14198  1.329843      8.0 -0.028487 -0.105944  0.025799      1
# 14199  1.836836     10.0 -0.060740 -0.101668  0.016025      1
# 14200  1.430832     10.0 -0.083220 -0.088474 -0.016717      1
# 14201  0.827205     11.0 -0.075401 -0.082732 -0.033333      1
# 14202  0.536214     11.0 -0.058053 -0.067704 -0.024170      1
#
# [2569 rows x 13 columns]
#
#
# Column: gyro_z
# IQR: 0.027855456149999902
# Lower Bound: -0.0615187141692526, Upper Bound: 0.04990311043074701
# Outliers Detected: 1871
#        Longitude   Latitude  Speed     Distance      Time     Acc X     Acc Y  \
# 98     73.822660  18.501627  0.000     0.025645  18-45-22  0.870786 -0.109471
# 99     73.822660  18.501627  0.000     0.025645  18-45-22  0.742543 -0.062337
# 162    73.822520  18.501616  0.732    14.906174  18-45-29 -0.103867  0.272178
# 167    73.822520  18.501616  0.732    14.906174  18-45-29 -1.555064  1.752859
# 168    73.822520  18.501616  0.732    14.906174  18-45-29 -1.107155  1.488280
# ...          ...        ...    ...          ...       ...       ...       ...
# 14185  73.822813  18.501587  0.000  2096.573200  17-27-28  0.434999 -1.207874
# 14186  73.822813  18.501587  0.000  2096.573200  17-27-28  0.559245 -0.635276
# 14192  73.822813  18.501587  0.000  2096.573200  17-27-29  1.229296  1.503951
# 14193  73.822813  18.501587  0.000  2096.573200  17-27-29  1.619212  1.501497
# 14194  73.822813  18.501587  0.000  2096.573200  17-27-29  0.675375  0.864747
#
#           Acc Z  Heading    gyro_x    gyro_y    gyro_z  label
# 98     0.336063    352.0 -0.040704 -0.011158  0.054652      0
# 99     0.166326    352.0 -0.032152 -0.010181  0.057218      0
# 162   -1.040949    354.0 -0.115107 -0.088494  0.054286      1
# 167   -4.026543    353.0  0.119587  0.020118 -0.081204      1
# 168   -1.124722    355.0  0.404006  0.036000 -0.100874      1
# ...         ...      ...       ...       ...       ...    ...
# 14185  1.199026      6.0  0.186171 -0.190366  0.066849      1
# 14186  0.509873      6.0  0.145488 -0.192565  0.073691      1
# 14192 -1.118551      6.0 -0.103867 -0.004296 -0.070962      1
# 14193 -1.127005      6.0 -0.135266 -0.000753 -0.120076      1
# 14194 -1.491367      6.0 -0.102524 -0.051211 -0.104071      1
#
# [1871 rows x 13 columns]
